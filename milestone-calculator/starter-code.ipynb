# %% [markdown]
# # Milestone: 簡易計算機 - 起始程式碼
#
# 這是您的計算機專案起始範本。請按照註解提示完成程式碼。

# %% [markdown]
# ---
#
# ## 🚀 程式碼框架
#
# 請在以下框架中填入您的程式碼：

# %%
# Milestone: 簡易計算機
# 作者：[請填入您的姓名]
# 日期：[請填入完成日期]

print("=== 歡迎使用簡易計算機 ===")
print("支援運算：+（加）、-（減）、*（乘）、/（除）")
print()

# TODO 1: 取得使用者輸入
# 提示：使用 input() 取得輸入，使用 float() 轉換數字
# 需要取得：第一個數字、運算符號、第二個數字

num1 = # 在這裡填入程式碼
operator = # 在這裡填入程式碼
num2 = # 在這裡填入程式碼

# TODO 2: 執行運算
# 提示：使用 if/elif/else 根據運算符號選擇運算
# 基礎版：只需要支援加法（+）
# 完整版：支援 +、-、*、/ 四種運算

# TODO 3: 顯示結果
# 提示：使用 f-string 格式化輸出
# 格式：數字1 運算符號 數字2 = 結果

# %% [markdown]
# ---
#
# ## 💡 基礎版本範例
#
# 如果您是初學者，可以先完成這個只支援加法的版本：

# %%
# 基礎版本提示：只支援加法的計算機
# 如果您是初學者，可以先完成這個只支援加法的版本
# 完整解答請參考 solution.ipynb

# TODO: 請根據提示完成以下程式碼
# 提示 1: 使用 input() 取得兩個數字，並用 float() 轉換
# 提示 2: 執行加法運算 (使用 + 運算子)
# 提示 3: 使用 f-string 格式化輸出結果

# 您的程式碼從這裡開始：
# print("=== 簡易加法計算機 ===")
# print()
# ... (填入您的程式碼)

# %% [markdown]
# ---
#
# ## 🔧 測試您的程式碼
#
# 完成程式碼後，請使用以下測試案例驗證：

# %% [markdown]
# ### 測試案例 1：基本運算
#
# **輸入**：10, +, 5
# **預期輸出**：`10.0 + 5.0 = 15.0`
#
# **輸入**：20, -, 8
# **預期輸出**：`20.0 - 8.0 = 12.0`
#
# **輸入**：7, *, 6
# **預期輸出**：`7.0 * 6.0 = 42.0`
#
# **輸入**：15, /, 3
# **預期輸出**：`15.0 / 3.0 = 5.0`

# %% [markdown]
# ### 測試案例 2：小數運算
#
# **輸入**：3.5, +, 2.5
# **預期輸出**：`3.5 + 2.5 = 6.0`
#
# **輸入**：10.5, /, 2
# **預期輸出**：`10.5 / 2.0 = 5.25`

# %% [markdown]
# ### 測試案例 3：負數運算
#
# **輸入**：-5, +, 3
# **預期輸出**：`-5.0 + 3.0 = -2.0`
#
# **輸入**：10, -, -5
# **預期輸出**：`10.0 - -5.0 = 15.0`

# %% [markdown]
# ---
#
# ## 🏆 進階挑戰
#
# 完成基本要求後，可以嘗試以下進階功能：

# %%
# 進階挑戰 1：錯誤處理
# 任務：處理除以零的情況
# 完整解答請參考 solution.ipynb

# TODO: 實作包含錯誤處理的計算機
# 提示：
# 1. 在除法運算前，檢查 num2 是否為 0
# 2. 如果 num2 == 0，顯示錯誤訊息並結束程式（使用 return）
# 3. 否則執行正常的除法運算

# 您的程式碼從這裡開始：
# def safe_calculator():
#     """包含錯誤處理的計算機"""
#     ...

# %%
# 進階挑戰 2：更多運算符號
# 任務：支援次方（**）、餘數（%）、整數除法（//）
# 完整解答請參考 solution.ipynb

# TODO: 實作支援更多運算符號的計算機
# 提示：
# 1. 使用 ** 運算子計算次方 (例如：2 ** 3 = 8)
# 2. 使用 % 運算子計算餘數 (例如：10 % 3 = 1)
# 3. 使用 // 運算子計算整數除法 (例如：10 // 3 = 3)
# 4. 記得檢查 % 和 // 的除零錯誤（與 / 相同）

# 您的程式碼從這裡開始：
# def advanced_calculator():
#     """進階計算機"""
#     ...

# %% [markdown]
# ---
#
# ## 📝 完成檢核表
#
# 完成程式碼後，請檢查以下項目：
#
# ### 基本要求
# - [ ] 程式可以正常執行
# - [ ] 正確取得使用者輸入
# - [ ] 至少支援加法運算
# - [ ] 使用 f-string 格式化輸出
# - [ ] 輸出格式為：`數字1 運算符號 數字2 = 結果`
#
# ### 程式品質
# - [ ] 變數名稱有意義
# - [ ] 有適當的註解
# - [ ] 程式碼縮排正確
# - [ ] 有使用者友善的提示訊息
#
# ### 進階功能（選做）
# - [ ] 支援四則運算（+, -, *, /）
# - [ ] 處理除以零的錯誤
# - [ ] 檢查運算符號的有效性
# - [ ] 支援更多運算（**, %, //）
#
# ### 測試驗證
# - [ ] 通過所有基本測試案例
# - [ ] 通過小數運算測試
# - [ ] 通過負數運算測試
# - [ ] （進階）通過錯誤處理測試
#
# ---
#
# ## 🎯 提交指南
#
# 1. **命名您的檔案**：
#    - Jupyter Notebook：`姓名_calculator.ipynb`
#    - Python 檔案：`姓名_calculator.py`
#
# 2. **程式碼要求**：
#    - 在檔案開頭加入您的姓名和完成日期
#    - 確保程式碼可以獨立執行
#    - 有清楚的註解說明
#
# 3. **測試證明**：
#    - 執行程式並截圖至少 3 個測試案例
#    - 或在 Notebook 中保留執行結果
#
# ---
#
# **祝您程式設計愉快！** 🚀
