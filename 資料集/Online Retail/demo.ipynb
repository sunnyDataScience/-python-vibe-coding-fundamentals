# %%
import pandas as pd
from pathlib import Path

# Get notebook directory
notebook_dir = Path.cwd()
print(f"Current working directory: {notebook_dir}")

# Build absolute paths
data_dir = Path(__file__).parent if '__file__' in globals() else Path.cwd()
file1 = data_dir / 'online_retail_09_10.csv'
file2 = data_dir / 'online_retail_10_11.csv'

# Load datasets
df_09_10 = pd.read_csv(file1, encoding='ISO-8859-1')
df_10_11 = pd.read_csv(file2, encoding='ISO-8859-1')

# Merge datasets by stacking them vertically
df_merged = pd.concat([df_09_10, df_10_11], ignore_index=True)
df_merged
